# %% [markdown]
# # Data Preprocessing

# %%
import pandas as pd

# %%
data=pd.read_csv('advertising.csv')

# %%
data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %% [markdown]
# # Data Visualisation

# %%
plt.figure(figsize=(10,6))
plt.scatter(data['TV'],data['Sales'])
plt.xlabel('TV advertisement')
plt.ylabel('Sales')
plt.title('Relationship between TV Advertisement and Sales')
plt.show()

# %%
plt.scatter(data['Radio'],data['Sales'])
plt.xlabel('Radio advertisement')
plt.ylabel('Sales')
plt.title('Relationship between Radio Advertisement and Sales')
plt.show()

# %%
plt.scatter(data['Newspaper'],data['Sales'])
plt.xlabel('Radio advertisement')
plt.ylabel('Sales')
plt.title('Relationship between Newspaper Advertisement and Sales')
plt.show()

# %% [markdown]
# # Clearly we can see, the tv advertisements have more influence with sales

# %% [markdown]
# # Correlation matrix

# %%
import seaborn as sns
sns.heatmap(data.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Considering tv column as x and sales as y

# %%
x=data['TV']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train=x_train.values.reshape(-1,1)
x_test=x_test.values.reshape(-1,1)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)

# %%
mse= r2_score(y_test, y_pred)
print("Mean Squared Error: ", mse)
# Out:
# Mean Squared Error:  0.802561303423698

# %%
import matplotlib.pyplot as plt


plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_pred, color='blue', alpha=0.5)  
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red') 
plt.title('Actual vs Predicted')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.grid(True)
plt.show()

# %% [markdown]
# # Considering tv,radio,newspaper as x and sales as y

# %%
x=data.drop('Sales',inplace=False,axis=1)
y=data['Sales']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)

# %%
from sklearn.metrics import r2_score
r_squared = r2_score(y_test, y_pred)
r_squared
# Out:
# 0.9059011844150826

# %%
import matplotlib.pyplot as plt


plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_pred, color='blue', alpha=0.5)  
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red')  
plt.title('Actual vs Predicted')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.grid(True)
plt.show()
